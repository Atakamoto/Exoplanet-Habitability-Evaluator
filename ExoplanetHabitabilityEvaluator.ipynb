# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning
# Dataset from Planetary Habitability Laboratory (University of Puerto Rico)

# %%
file_path = 'data/hwc.csv'
exoplanets = pd.read_csv(file_path)

# %%
exoplanets.head(10)
# Out:
#                   P_NAME      P_DETECTION  \
# 0  OGLE-2016-BLG-1227L b     Microlensing
# 1           Kepler-276 c          Transit
# 2           Kepler-829 b          Transit
# 3               K2-283 b          Transit
# 4           Kepler-477 b          Transit
# 5             TOI-1260 c          Transit
# 6            HD 149143 b  Radial Velocity
# 7             HD 99492 b  Radial Velocity
# 8               nu Oph c  Radial Velocity
# 9               75 Cet b  Radial Velocity
#
#                            P_DISCOVERY_FACILITY  P_YEAR    P_UPDATE  \
# 0                                          OGLE    2020  2020-04-02
# 1                                        Kepler    2013  2018-09-25
# 2                                        Kepler    2016  2019-04-16
# 3                                            K2    2018  2019-09-05
# 4                                        Kepler    2016  2019-04-16
# 5  Transiting Exoplanet Survey Satellite (TESS)    2021  2022-12-17
# ...

# %%
print(exoplanets.columns.values)
# Out:
# ['P_NAME' 'P_DETECTION' 'P_DISCOVERY_FACILITY' 'P_YEAR' 'P_UPDATE'
#  'P_MASS' 'P_MASS_ERROR_MIN' 'P_MASS_ERROR_MAX' 'P_MASS_LIMIT'
#  'P_MASS_ORIGIN' 'P_RADIUS' 'P_RADIUS_ERROR_MIN' 'P_RADIUS_ERROR_MAX'
#  'P_RADIUS_LIMIT' 'P_PERIOD' 'P_PERIOD_ERROR_MIN' 'P_PERIOD_ERROR_MAX'
#  'P_PERIOD_LIMIT' 'P_SEMI_MAJOR_AXIS' 'P_SEMI_MAJOR_AXIS_ERROR_MIN'
#  'P_SEMI_MAJOR_AXIS_ERROR_MAX' 'P_SEMI_MAJOR_AXIS_LIMIT' 'P_ECCENTRICITY'
#  'P_ECCENTRICITY_ERROR_MIN' 'P_ECCENTRICITY_ERROR_MAX'
#  'P_ECCENTRICITY_LIMIT' 'P_INCLINATION' 'P_INCLINATION_ERROR_MIN'
#  'P_INCLINATION_ERROR_MAX' 'P_INCLINATION_LIMIT' 'P_OMEGA'
#  'P_OMEGA_ERROR_MIN' 'P_OMEGA_ERROR_MAX' 'P_OMEGA_LIMIT' 'S_NAME'
#  'S_NAME_HD' 'S_NAME_HIP' 'S_TYPE' 'S_RA' 'S_DEC' 'S_RA_STR' 'S_DEC_STR'
#  'S_MAG' 'S_MAG_ERROR_MIN' 'S_MAG_ERROR_MAX' 'S_DISTANCE'
#  'S_DISTANCE_ERROR_MIN' 'S_DISTANCE_ERROR_MAX' 'S_TEMPERATURE'
#  'S_TEMPERATURE_ERROR_MIN' 'S_TEMPERATURE_ERROR_MAX' 'S_TEMPERATURE_LIMIT'
# ...

# %%
exoplanets.shape
# Out:
# (5599, 118)

# %% [markdown]
# Only using columns from simplified version to allow for further understanding of features and to allow for easier management of data

# %%
exoplanets_simp = exoplanets[['S_AGE', 'P_TEMP_SURF', 'P_FLUX', 'P_RADIUS', 'P_TYPE', 'P_MASS', 'P_HABITABLE']]
exoplanets_simp
# Out:
#       S_AGE  P_TEMP_SURF      P_FLUX  P_RADIUS       P_TYPE     P_MASS  \
# 0       NaN          NaN         NaN     13.90       Jovian  250.00000
# 1      0.40          NaN   20.490365      2.90    Neptunian   16.60000
# 2      4.68   1130.60440  238.528680      2.11  Superterran    5.10000
# 3       NaN          NaN  353.357260      3.52    Neptunian   12.20000
# 4      2.09    769.42507   51.163853      2.07  Superterran    4.94000
# ...     ...          ...         ...       ...          ...        ...
# 5594   8.20          NaN    0.123796     13.40       Jovian  581.62598
# 5595   7.90          NaN    7.568789      2.49    Neptunian   17.20000
# 5596   2.00          NaN   17.899396      3.90    Neptunian   11.30000
# 5597   7.80    890.78087   92.918155      1.92  Superterran    4.33000
# 5598    NaN          NaN         NaN     13.50       Jovian  555.24623
#
#       P_HABITABLE
# 0               0
# 1               0
# 2               0
# 3               0
# ...

# %%
exoplanets_simp.isnull().sum()
# Out:
# S_AGE          1207
# P_TEMP_SURF    3158
# P_FLUX          234
# P_RADIUS          7
# P_TYPE            7
# P_MASS            7
# P_HABITABLE       0
# dtype: int64

# %% [markdown]
# ## First Attempt at Cleaning Data

# %%
exoplanets_clean = exoplanets_simp.dropna()
exoplanets_clean
# Out:
#       S_AGE  P_TEMP_SURF       P_FLUX  P_RADIUS       P_TYPE  P_MASS  \
# 2      4.68   1130.60440   238.528680     2.110  Superterran   5.100
# 4      2.09    769.42507    51.163853     2.070  Superterran   4.940
# 13     4.30   1504.26870   766.125920     1.402       Terran   3.400
# 22     1.30    746.01801    48.505343     2.180  Superterran   7.320
# 27     4.60   1354.17430   492.983910     2.160  Superterran   7.250
# ...     ...          ...          ...       ...          ...     ...
# 5587  12.20    926.69044   107.655610     1.459       Terran   2.730
# 5588   6.30   1670.50010  1136.799700     0.740    Subterran   0.330
# 5589   1.10   1654.49390  1093.852000     0.860       Terran   0.566
# 5590   4.00   1243.25990   348.775190     1.610  Superterran   3.220
# 5597   7.80    890.78087    92.918155     1.920  Superterran   4.330
#
#       P_HABITABLE
# 2               0
# 4               0
# 13              0
# 22              0
# 27              0
# ...           ...
# ...

# %%
# Convert categorical column to numerical using one-hot encoding
exoplanets_clean = pd.get_dummies(exoplanets_clean, columns=['P_TYPE'])  # Replace 'P_TYPE' with actual column name

# %% [markdown]
# For P_HABITABLE columns the website lists:\
# 0: not habitable\
# 1: conservative\
# 2: optimistic

# %% [markdown]
# Checking to see how percentage of habitable planets change when rows are dropped

# %%
count = exoplanets_simp[exoplanets_simp['P_HABITABLE'] >= 1]
print("Percent of habitable in simp_data: " + str(count.size/exoplanets_simp.size))

count_clean = exoplanets_clean[exoplanets_clean['P_HABITABLE'] >= 1]
print("Percent of habitable in clean_data: " + str(count_clean.size/exoplanets_clean.size))
# Out:
# Percent of habitable in simp_data: 0.012502232541525273
# Percent of habitable in clean_data: 0.025115325474115838

# %%
count_clean = exoplanets_clean['P_HABITABLE'].value_counts()
count_clean
# Out:
# P_HABITABLE
# 0    1902
# 2      27
# 1      22
# Name: count, dtype: int64

# %% [markdown]
# Percentage increases by about a percentage point. Since the habitable planet percentage doubles, dropping nas may not be the best so will look to improve this in the future.

# %% [markdown]
# ## Updated Attempt at Cleaning Data

# %%
from sklearn.impute import KNNImputer
exoplanets_clean_final = exoplanets_simp.copy()

imputer = KNNImputer(n_neighbors=5)
exoplanets_clean_final[['S_AGE', 'P_TEMP_SURF', 'P_FLUX', 'P_RADIUS', 'P_MASS']] = imputer.fit_transform(exoplanets_simp[['S_AGE', 'P_TEMP_SURF', 'P_FLUX', 'P_RADIUS', 'P_MASS']])

# %%
# Replace NaN values in P_HABITABLE with 0
exoplanets_clean_final['P_HABITABLE'] = exoplanets_clean_final['P_HABITABLE'].fillna(0)

# %%
exoplanets_clean_final.isnull().sum()
# Out:
# S_AGE          0
# P_TEMP_SURF    0
# P_FLUX         0
# P_RADIUS       0
# P_TYPE         7
# P_MASS         0
# P_HABITABLE    0
# dtype: int64

# %%
exoplanets_clean_final = exoplanets_clean_final.dropna()

# %%
exoplanets_clean_final
# Out:
#        S_AGE  P_TEMP_SURF      P_FLUX  P_RADIUS       P_TYPE     P_MASS  \
# 0     5.3800   930.014468  127.304967     13.90       Jovian  250.00000
# 1     0.4000   615.236200   20.490365      2.90    Neptunian   16.60000
# 2     4.6800  1130.604400  238.528680      2.11  Superterran    5.10000
# 3     3.8280  1247.125180  353.357260      3.52    Neptunian   12.20000
# 4     2.0900   769.425070   51.163853      2.07  Superterran    4.94000
# ...      ...          ...         ...       ...          ...        ...
# 5594  8.2000   834.556686    0.123796     13.40       Jovian  581.62598
# 5595  7.9000   445.894714    7.568789      2.49    Neptunian   17.20000
# 5596  2.0000   585.157848   17.899396      3.90    Neptunian   11.30000
# 5597  7.8000   890.780870   92.918155      1.92  Superterran    4.33000
# 5598  3.2144  1198.113952  160.753407     13.50       Jovian  555.24623
#
#       P_HABITABLE
# 0               0
# 1               0
# 2               0
# 3               0
# ...

# %%
# Convert categorical column to numerical using one-hot encoding
exoplanets_clean_final = pd.get_dummies(exoplanets_clean_final, columns=['P_TYPE'])  # Replace 'P_TYPE' with actual column name

# %% [markdown]
# ## EDA

# %%
exoplanets_clean_final.dtypes
# Out:
# S_AGE                 float64
# P_TEMP_SURF           float64
# P_FLUX                float64
# P_RADIUS              float64
# P_MASS                float64
# P_HABITABLE             int64
# P_TYPE_Jovian            bool
# P_TYPE_Miniterran        bool
# P_TYPE_Neptunian         bool
# P_TYPE_Subterran         bool
# P_TYPE_Superterran       bool
# P_TYPE_Terran            bool
# dtype: object

# %%
exo_corr = exoplanets_clean_final.apply(pd.to_numeric, errors='ignore', downcast='float').select_dtypes(include=['float64', 'float32']).corr()
plt.figure(figsize=(12, 8))  
sns.heatmap(exo_corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap of Correlations')
plt.show()

# %% [markdown]
# ## Initial Model Testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from xgboost import XGBClassifier

# %%
# Convert P_HABITABLE to binary (1 if >= 1, else 0)
exoplanets_clean_final['P_HABITABLE'] = exoplanets_clean_final['P_HABITABLE'].apply(lambda x: 1 if x >= 1 else 0)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(exoplanets_clean_final.drop(columns=['P_HABITABLE']), 
                                                    exoplanets_clean_final['P_HABITABLE'], 
                                                    test_size=0.25, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %%
# Create logistic regression model
modelLR = LogisticRegression()
modelLR.fit(X_train, y_train) 

# Predict on the test set
y_pred = modelLR.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Output results
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.9978540772532188
# Confusion Matrix:
#  [[1380    2]
#  [   1   15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1382
#            1       0.88      0.94      0.91        16
#
#     accuracy                           1.00      1398
#    macro avg       0.94      0.97      0.95      1398
# weighted avg       1.00      1.00      1.00      1398

# %% [markdown]
# ### XGBoost

# %%
# Create XGBoost model
model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Output results
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.9985693848354793
# Confusion Matrix:
#  [[1381    1]
#  [   1   15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1382
#            1       0.94      0.94      0.94        16
#
#     accuracy                           1.00      1398
#    macro avg       0.97      0.97      0.97      1398
# weighted avg       1.00      1.00      1.00      1398
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [13:26:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# ## Saving Model

# %%
import pickle

# Save the model to a file
with open('xgboost_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
# Save the model to a file
with open('logR_model.pkl', 'wb') as f:
    pickle.dump(modelLR, f)

# %% [markdown]
# Overall when testing the Logistic Regression model performed better so it is the model used in the streamlit app
